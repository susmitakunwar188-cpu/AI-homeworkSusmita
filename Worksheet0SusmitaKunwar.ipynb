# %%
#TASK-1

# Daily time (in hours): [study, entertainment, sleep]
time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

low = []
moderate = []
high = []

for i in time_data:
    if i[0] < 3:
        low.append(i)
    elif 3 <= i[0] < 5:
        moderate.append(i)
    else:
        high.append(i)

print("The study time less than 3 hours:",low)
print("The study time between 3 and 5 hours:",moderate)
print("The study time more than 5 hours:", high)
# Out:
# The study time less than 3 hours: [(2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0)]
# The study time between 3 and 5 hours: [(3.5, 2.0, 7.0), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (3.5, 2.5, 7.0)]
# The study time more than 5 hours: [(5.0, 1.5, 6.5), (5.5, 1.0, 6.0), (6.0, 1.5, 6.0), (5.0, 2.0, 6.5)]

# %%
#TASK-2
low_study_time = len(low)
moderate_study_time = len(moderate)
high_study_time = len(high)

print("The number of days that had low study time is:", len(low))
print("The number of days that had moderate study time is:", len(moderate))
print("The number of days that had high study time is:", len(high))
# Out:
# The number of days that had low study time is: 4
# The number of days that had moderate study time is: 7
# The number of days that had high study time is: 4

# %%
#TASK-3
study_minutes =[]
for i in time_data:
    study_minutes.append(i[0]*60)
print(study_minutes)
# Out:
# [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
#TASK-4
study_hours =[]
entertainment_hours =[]
sleep_hours = []

for i in time_data:
    study_hours.append(i[0])
    entertainment_hours.append(i[1])
    sleep_hours.append(i[2])

print("The average hours spent studying is:", (sum(study_hours)/len(study_hours)))
print("The average hours spent on entertainment is:", (sum(entertainment_hours)/len(entertainment_hours)))
print("The average hours spent sleeping is:", (sum(sleep_hours)/len(sleep_hours)))
# Out:
# The average hours spent studying is: 3.7
# The average hours spent on entertainment is: 2.5
# The average hours spent sleeping is: 7.166666666666667

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nitro\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
#TASK-5
import matplotlib.pyplot as plt
plt.scatter(study_hours, sleep_hours, color="brown")
plt.xlabel("StudyHours")
plt.ylabel("SleepHours")
plt.title("study hours and sleep hours ")
plt.show()

# %%
# 8.1.1 RECURSION
#TASK-1
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
def sum_nested_list(nested_list):
    total = 0
    for element in nested_list:
        if isinstance(element,list): # Check if the element is a list
            total += sum_nested_list(element) # Recursively sum the nested lis
        else:
            total += element # Add the number to the total
    return total

print("sum nested list is:", sum_nested_list(nested_list))
# Out:
# sum nested list is: 36

# %%
#TASK-2
def generate_permutations(s):
    if len(s) <= 1:
        return [s]
    
    perms = []
    for i, char in enumerate(s):
        
        remaining = s[:i] + s[i+1:]
        
        for p in generate_permutations(remaining):
            perms.append(char + p)
    
    return perms

print(generate_permutations("xyz"))
# Out:
# ['xyz', 'xzy', 'yxz', 'yzx', 'zxy', 'zyx']

# %%
#Task-3

# Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

def calculate_directory_size(directory):
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value
    return total_size


total = calculate_directory_size(directory_structure)
print(f"Total directory size: {total} KB")
# Out:
# Total directory size: 1400 KB

# %%
#8.2.1
#TASK-2
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0]*(n+1) for _ in range(m+1)]

    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    i, j = m, n
    lcs_str = ""
    while i > 0 and j > 0:
        if s1[i-1] == s2[j-1]:
            lcs_str = s1[i-1] + lcs_str
            i -= 1
            j -= 1
        elif dp[i-1][j] > dp[i][j-1]:
            i -= 1
        else:
            j -= 1
    print("LCS:", lcs_str)
    print("LCS length:", dp[m][n])
longest_common_subsequence("Susmita", "suspicious")
# Out:
# LCS: usi
# LCS length: 3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]
    
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(values[i - 1] + dp[i - 1][w - weights[i - 1]], dp[i - 1][w])
            else:
                dp[i][w] = dp[i - 1][w]
    
    return dp[n][capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print("Maximum value:", knapsack(weights, values, capacity))
# Out:
# Maximum value: 9
